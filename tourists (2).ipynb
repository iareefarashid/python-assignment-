# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv("Tourists.csv")

# %%
df
# Out:
#                         Name  \
# 0                 Ansoo Lake
# 1              Astola Island
# 2               Attabad Lake
# 3            Badshahi Mosque
# 4            Baltoro Glacier
# ..                       ...
# 64             Taxila Museum
# 65               Thal Desert
# 66         The Lahore Museum
# 67  Umbrella Waterfall Poona
# 68            West Bay Beach
#
#                                                  Desc     category  \
# 0   Ansoo Lake is situated in Kaghan Valley of Pak...         Lake
# 1   Astola Island, also known as Jezira Haft Talar...       Island
# 2   Attabad Lake is a lake in the Gojal Valley of ...         Lake
# 3   The Badshahi Mosque is a Mughal-era congregati...       Mosque
# 4   The Baltoro Glacier, at 63 km (39 mi) in lengt...  Mountainous
# ..                                                ...          ...
# 64  Taxila Museum is located at Taxila, Punjab, Pa...       Museum
# ...

# %%
df.head(10)
# Out:
#                         Name  \
# 0                 Ansoo Lake
# 1              Astola Island
# 2               Attabad Lake
# 3            Badshahi Mosque
# 4            Baltoro Glacier
# 5                    Bhurban
# 6  Bruti waterfall Islamabad
# 7                  Concordia
# 8       Deosai National Park
# 9               Derawar Fort
#
#                                                 Desc       category  \
# 0  Ansoo Lake is situated in Kaghan Valley of Pak...           Lake
# 1  Astola Island, also known as Jezira Haft Talar...         Island
# 2  Attabad Lake is a lake in the Gojal Valley of ...           Lake
# 3  The Badshahi Mosque is a Mughal-era congregati...         Mosque
# 4  The Baltoro Glacier, at 63 km (39 mi) in lengt...    Mountainous
# 5  Bhurban is a small town resort and hill statio...   Hill Station
# 6  Bruti waterfall is 3 km from Bari Imam Islamab...      Waterfall
# 7  Amongst the tallest 14 mountain peaks of the w...    Mountainous
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Desc', 'category', 'district', 'latitude', 'longitude'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=69, step=1)

# %%
df["Name"]
# Out:
# 0                   Ansoo Lake
# 1                Astola Island
# 2                 Attabad Lake
# 3              Badshahi Mosque
# 4              Baltoro Glacier
#                 ...
# 64               Taxila Museum
# 65                 Thal Desert
# 66           The Lahore Museum
# 67    Umbrella Waterfall Poona
# 68              West Bay Beach
# Name: Name, Length: 69, dtype: object

# %%
df.Name
# Out:
# 0                   Ansoo Lake
# 1                Astola Island
# 2                 Attabad Lake
# 3              Badshahi Mosque
# 4              Baltoro Glacier
#                 ...
# 64               Taxila Museum
# 65                 Thal Desert
# 66           The Lahore Museum
# 67    Umbrella Waterfall Poona
# 68              West Bay Beach
# Name: Name, Length: 69, dtype: object

# %%
df[["Name","latitude"]]
# Out:
#                         Name   latitude
# 0                 Ansoo Lake  34.814119
# 1              Astola Island  25.122321
# 2               Attabad Lake  36.345827
# 3            Badshahi Mosque  31.588126
# 4            Baltoro Glacier  35.710642
# ..                       ...        ...
# 64             Taxila Museum  33.745900
# 65               Thal Desert  31.228100
# 66         The Lahore Museum  31.568400
# 67  Umbrella Waterfall Poona  33.977090
# 68            West Bay Beach  25.159400
#
# [69 rows x 2 columns]

# %%
df["Name"]
# Out:
# 0                   Ansoo Lake
# 1                Astola Island
# 2                 Attabad Lake
# 3              Badshahi Mosque
# 4              Baltoro Glacier
#                 ...
# 64               Taxila Museum
# 65                 Thal Desert
# 66           The Lahore Museum
# 67    Umbrella Waterfall Poona
# 68              West Bay Beach
# Name: Name, Length: 69, dtype: object

# %%
names= df["Name"]

# %%
names
# Out:
# 0                   Ansoo Lake
# 1                Astola Island
# 2                 Attabad Lake
# 3              Badshahi Mosque
# 4              Baltoro Glacier
#                 ...
# 64               Taxila Museum
# 65                 Thal Desert
# 66           The Lahore Museum
# 67    Umbrella Waterfall Poona
# 68              West Bay Beach
# Name: Name, Length: 69, dtype: object

# %%
names[0]
# Out:
# 'Ansoo Lake'

# %%
names[1:4]
# Out:
# 1      Astola Island
# 2       Attabad Lake
# 3    Badshahi Mosque
# Name: Name, dtype: object

# %%
names[[1,2,4]]
# Out:
# 1      Astola Island
# 2       Attabad Lake
# 4    Baltoro Glacier
# Name: Name, dtype: object

# %%
first_name= df.loc[0, "Name"]

# %%
first_name
# Out:
# 'Ansoo Lake'

# %%
first_row = df.loc[0,:]

# %%
first_row
# Out:
# Name                                                Ansoo Lake
# Desc         Ansoo Lake is situated in Kaghan Valley of Pak...
# category                                                  Lake
# district                                    Khyber Pakhtunkhwa
# latitude                                             34.814119
# longitude                                            73.676428
# Name: 0, dtype: object

# %%
slice_one =df.loc[0:2, "Name" : "latitude"]

# %%
slice_one
# Out:
#             Name                                               Desc category  \
# 0     Ansoo Lake  Ansoo Lake is situated in Kaghan Valley of Pak...     Lake
# 1  Astola Island  Astola Island, also known as Jezira Haft Talar...   Island
# 2   Attabad Lake  Attabad Lake is a lake in the Gojal Valley of ...     Lake
#
#              district   latitude
# 0  Khyber Pakhtunkhwa  34.814119
# 1         Balochistan  25.122321
# 2    Gilgit−Baltistan  36.345827

# %%
slice_two = df.loc[[0,2,3], ["Name","latitude"]]

# %%
slice_two
# Out:
#               Name   latitude
# 0       Ansoo Lake  34.814119
# 2     Attabad Lake  36.345827
# 3  Badshahi Mosque  31.588126

# %%
df.latitude.mean()
# Out:
# 32.83930327652173

# %%
avg_latitude=df.latitude.mean()

# %%
avg_latitude
# Out:
# 32.83930327652173

# %%
latitude =df["latitude"].max()

# %%
latitude
# Out:
# 36.8784107

# %%
summary_df=df.describe()

# %%
summary_df
# Out:
#         latitude  longitude
# count  69.000000  69.000000
# mean   32.839303  72.536530
# std     3.511483   3.258586
# min    24.814200  62.049984
# 25%    31.588126  72.579600
# 50%    33.858400  73.482380
# 75%    35.330300  74.309500
# max    36.878411  76.553142

# %%
summary_df=df.describe()

# %%
summary_df[["latitude"]]
# Out:
#         latitude
# count  69.000000
# mean   32.839303
# std     3.511483
# min    24.814200
# 25%    31.588126
# 50%    33.858400
# 75%    35.330300
# max    36.878411

# %%
df["longitude"].value_counts()
# Out:
# longitude
# 74.309322    2
# 73.676428    1
# 73.384519    1
# 73.005843    1
# 73.532500    1
#             ..
# 74.314956    1
# 73.695723    1
# 66.726700    1
# 72.651000    1
# 62.181600    1
# Name: count, Length: 68, dtype: int64

# %%
df["longitude"].unique()
# Out:
# array([73.67642783, 63.84794782, 74.86543579, 74.30932246, 76.55314235,
#        73.4518727 , 73.1139125 , 76.5118925 , 75.47983135, 71.33424735,
#        73.6911    , 74.57892916, 73.03736   , 75.9999    , 62.0499838 ,
#        74.8632045 , 67.1511368 , 73.86825122, 65.530701  , 74.65      ,
#        73.2877772 , 72.1941226 , 72.5796    , 71.6554    , 72.2474823 ,
#        73.70117513, 72.9516404 , 73.0062054 , 73.52379989, 74.31495649,
#        73.6957232 , 66.7267    , 72.651     , 72.5722    , 75.9947968 ,
#        74.3236    , 72.6595    , 74.3095    , 67.033     , 68.1357    ,
#        66.6405599 , 74.0821    , 73.5289869 , 73.384519  , 73.9073    ,
#        73.117348  , 67.0961    , 73.0689    , 73.5325    , 73.005843  ,
#        73.1084    , 74.7856    , 74.0625    , 73.7654    , 73.5745    ,
#        74.8825    , 73.278766  , 75.6295    , 74.3828    , 75.4567    ,
#        73.17057   , 75.551     , 66.96973   , 72.8187    , 71.8099    ,
# ...

# %%
unique_values=df["longitude"].unique()

# %%
unique_values[0]
# Out:
# 73.67642783

# %%
len(unique_values)
# Out:
# 68

# %%
df.shape
# Out:
# (69, 6)

# %%
df.dtypes
# Out:
# Name          object
# Desc          object
# category      object
# district      object
# latitude     float64
# longitude    float64
# dtype: object

# %%
df.head()
# Out:
#               Name                                               Desc  \
# 0       Ansoo Lake  Ansoo Lake is situated in Kaghan Valley of Pak...
# 1    Astola Island  Astola Island, also known as Jezira Haft Talar...
# 2     Attabad Lake  Attabad Lake is a lake in the Gojal Valley of ...
# 3  Badshahi Mosque  The Badshahi Mosque is a Mughal-era congregati...
# 4  Baltoro Glacier  The Baltoro Glacier, at 63 km (39 mi) in lengt...
#
#       category            district   latitude  longitude
# 0         Lake  Khyber Pakhtunkhwa  34.814119  73.676428
# 1       Island         Balochistan  25.122321  63.847948
# 2         Lake    Gilgit−Baltistan  36.345827  74.865436
# 3       Mosque              Punjab  31.588126  74.309322
# 4  Mountainous    Gilgit−Baltistan  35.710642  76.553142

# %%
df["latitude"].mean()
# Out:
# 32.83930327652173

# %%
df["new_column"]=1

# %%
df.head()
# Out:
#               Name                                               Desc  \
# 0       Ansoo Lake  Ansoo Lake is situated in Kaghan Valley of Pak...
# 1    Astola Island  Astola Island, also known as Jezira Haft Talar...
# 2     Attabad Lake  Attabad Lake is a lake in the Gojal Valley of ...
# 3  Badshahi Mosque  The Badshahi Mosque is a Mughal-era congregati...
# 4  Baltoro Glacier  The Baltoro Glacier, at 63 km (39 mi) in lengt...
#
#       category            district   latitude  longitude  new_column
# 0         Lake  Khyber Pakhtunkhwa  34.814119  73.676428           1
# 1       Island         Balochistan  25.122321  63.847948           1
# 2         Lake    Gilgit−Baltistan  36.345827  74.865436           1
# 3       Mosque              Punjab  31.588126  74.309322           1
# 4  Mountainous    Gilgit−Baltistan  35.710642  76.553142           1

# %%
df["latitude_Percentage"]=df["latitude"]/36

# %%
df.head()
# Out:
#               Name                                               Desc  \
# 0       Ansoo Lake  Ansoo Lake is situated in Kaghan Valley of Pak...
# 1    Astola Island  Astola Island, also known as Jezira Haft Talar...
# 2     Attabad Lake  Attabad Lake is a lake in the Gojal Valley of ...
# 3  Badshahi Mosque  The Badshahi Mosque is a Mughal-era congregati...
# 4  Baltoro Glacier  The Baltoro Glacier, at 63 km (39 mi) in lengt...
#
#       category            district   latitude  longitude  new_column  \
# 0         Lake  Khyber Pakhtunkhwa  34.814119  73.676428           1
# 1       Island         Balochistan  25.122321  63.847948           1
# 2         Lake    Gilgit−Baltistan  36.345827  74.865436           1
# 3       Mosque              Punjab  31.588126  74.309322           1
# 4  Mountainous    Gilgit−Baltistan  35.710642  76.553142           1
#
#    latitude_Percentage
# 0             0.967059
# 1             0.697842
# 2             1.009606
# 3             0.877448
# ...

# %%
del df["latitude_Percentage"]

# %%
df.head()
# Out:
#               Name                                               Desc  \
# 0       Ansoo Lake  Ansoo Lake is situated in Kaghan Valley of Pak...
# 1    Astola Island  Astola Island, also known as Jezira Haft Talar...
# 2     Attabad Lake  Attabad Lake is a lake in the Gojal Valley of ...
# 3  Badshahi Mosque  The Badshahi Mosque is a Mughal-era congregati...
# 4  Baltoro Glacier  The Baltoro Glacier, at 63 km (39 mi) in lengt...
#
#       category            district   latitude  longitude  new_column
# 0         Lake  Khyber Pakhtunkhwa  34.814119  73.676428           1
# 1       Island         Balochistan  25.122321  63.847948           1
# 2         Lake    Gilgit−Baltistan  36.345827  74.865436           1
# 3       Mosque              Punjab  31.588126  74.309322           1
# 4  Mountainous    Gilgit−Baltistan  35.710642  76.553142           1

# %%
df.drop(["new_column","latitude"], axis=1, inplace=True)

# %%
df.head()
# Out:
#               Name                                               Desc  \
# 0       Ansoo Lake  Ansoo Lake is situated in Kaghan Valley of Pak...
# 1    Astola Island  Astola Island, also known as Jezira Haft Talar...
# 2     Attabad Lake  Attabad Lake is a lake in the Gojal Valley of ...
# 3  Badshahi Mosque  The Badshahi Mosque is a Mughal-era congregati...
# 4  Baltoro Glacier  The Baltoro Glacier, at 63 km (39 mi) in lengt...
#
#       category            district  longitude
# 0         Lake  Khyber Pakhtunkhwa  73.676428
# 1       Island         Balochistan  63.847948
# 2         Lake    Gilgit−Baltistan  74.865436
# 3       Mosque              Punjab  74.309322
# 4  Mountainous    Gilgit−Baltistan  76.553142

# %%
df["new_column"]=1

# %%
df.head()
# Out:
#               Name                                               Desc  \
# 0       Ansoo Lake  Ansoo Lake is situated in Kaghan Valley of Pak...
# 1    Astola Island  Astola Island, also known as Jezira Haft Talar...
# 2     Attabad Lake  Attabad Lake is a lake in the Gojal Valley of ...
# 3  Badshahi Mosque  The Badshahi Mosque is a Mughal-era congregati...
# 4  Baltoro Glacier  The Baltoro Glacier, at 63 km (39 mi) in lengt...
#
#       category            district  longitude  new_column
# 0         Lake  Khyber Pakhtunkhwa  73.676428           1
# 1       Island         Balochistan  63.847948           1
# 2         Lake    Gilgit−Baltistan  74.865436           1
# 3       Mosque              Punjab  74.309322           1
# 4  Mountainous    Gilgit−Baltistan  76.553142           1

# %%
df.drop("new_column", axis=1, inplace=True)

# %%
df
# Out:
#                         Name  \
# 0                 Ansoo Lake
# 1              Astola Island
# 2               Attabad Lake
# 3            Badshahi Mosque
# 4            Baltoro Glacier
# ..                       ...
# 64             Taxila Museum
# 65               Thal Desert
# 66         The Lahore Museum
# 67  Umbrella Waterfall Poona
# 68            West Bay Beach
#
#                                                  Desc     category  \
# 0   Ansoo Lake is situated in Kaghan Valley of Pak...         Lake
# 1   Astola Island, also known as Jezira Haft Talar...       Island
# 2   Attabad Lake is a lake in the Gojal Valley of ...         Lake
# 3   The Badshahi Mosque is a Mughal-era congregati...       Mosque
# 4   The Baltoro Glacier, at 63 km (39 mi) in lengt...  Mountainous
# ..                                                ...          ...
# 64  Taxila Museum is located at Taxila, Punjab, Pa...       Museum
# ...

# %%
df["new_column"]=1

# %%
df
# Out:
#                         Name  \
# 0                 Ansoo Lake
# 1              Astola Island
# 2               Attabad Lake
# 3            Badshahi Mosque
# 4            Baltoro Glacier
# ..                       ...
# 64             Taxila Museum
# 65               Thal Desert
# 66         The Lahore Museum
# 67  Umbrella Waterfall Poona
# 68            West Bay Beach
#
#                                                  Desc     category  \
# 0   Ansoo Lake is situated in Kaghan Valley of Pak...         Lake
# 1   Astola Island, also known as Jezira Haft Talar...       Island
# 2   Attabad Lake is a lake in the Gojal Valley of ...         Lake
# 3   The Badshahi Mosque is a Mughal-era congregati...       Mosque
# 4   The Baltoro Glacier, at 63 km (39 mi) in lengt...  Mountainous
# ..                                                ...          ...
# 64  Taxila Museum is located at Taxila, Punjab, Pa...       Museum
# ...

# %%
df.drop("new_column", axis=1, inplace=False)
# Out:
#                         Name  \
# 0                 Ansoo Lake
# 1              Astola Island
# 2               Attabad Lake
# 3            Badshahi Mosque
# 4            Baltoro Glacier
# ..                       ...
# 64             Taxila Museum
# 65               Thal Desert
# 66         The Lahore Museum
# 67  Umbrella Waterfall Poona
# 68            West Bay Beach
#
#                                                  Desc     category  \
# 0   Ansoo Lake is situated in Kaghan Valley of Pak...         Lake
# 1   Astola Island, also known as Jezira Haft Talar...       Island
# 2   Attabad Lake is a lake in the Gojal Valley of ...         Lake
# 3   The Badshahi Mosque is a Mughal-era congregati...       Mosque
# 4   The Baltoro Glacier, at 63 km (39 mi) in lengt...  Mountainous
# ..                                                ...          ...
# 64  Taxila Museum is located at Taxila, Punjab, Pa...       Museum
# ...

# %%
df
# Out:
#                         Name  \
# 0                 Ansoo Lake
# 1              Astola Island
# 2               Attabad Lake
# 3            Badshahi Mosque
# 4            Baltoro Glacier
# ..                       ...
# 64             Taxila Museum
# 65               Thal Desert
# 66         The Lahore Museum
# 67  Umbrella Waterfall Poona
# 68            West Bay Beach
#
#                                                  Desc     category  \
# 0   Ansoo Lake is situated in Kaghan Valley of Pak...         Lake
# 1   Astola Island, also known as Jezira Haft Talar...       Island
# 2   Attabad Lake is a lake in the Gojal Valley of ...         Lake
# 3   The Badshahi Mosque is a Mughal-era congregati...       Mosque
# 4   The Baltoro Glacier, at 63 km (39 mi) in lengt...  Mountainous
# ..                                                ...          ...
# 64  Taxila Museum is located at Taxila, Punjab, Pa...       Museum
# ...

# %%
df.drop([0,2], axis=0, inplace=False)
# Out:
#                          Name  \
# 1               Astola Island
# 3             Badshahi Mosque
# 4             Baltoro Glacier
# 5                     Bhurban
# 6   Bruti waterfall Islamabad
# ..                        ...
# 64              Taxila Museum
# 65                Thal Desert
# 66          The Lahore Museum
# 67   Umbrella Waterfall Poona
# 68             West Bay Beach
#
#                                                  Desc      category  \
# 1   Astola Island, also known as Jezira Haft Talar...        Island
# 3   The Badshahi Mosque is a Mughal-era congregati...        Mosque
# 4   The Baltoro Glacier, at 63 km (39 mi) in lengt...   Mountainous
# 5   Bhurban is a small town resort and hill statio...  Hill Station
# 6   Bruti waterfall is 3 km from Bari Imam Islamab...     Waterfall
# ..                                                ...           ...
# 64  Taxila Museum is located at Taxila, Punjab, Pa...        Museum
# ...

# %%
df.sort_values(by = "longitude", inplace=True, ascending=True)

# %%
df.head()
# Out:
#                     Name                                               Desc  \
# 15               Gawadar  Gwadar is a port city on the southwestern coas...
# 68        West Bay Beach  The West Bay Beach lies on the Makran coast, a...
# 1          Astola Island  Astola Island, also known as Jezira Haft Talar...
# 19  Hingol National Park  Hingol national park stretches out to approxim...
# 41          Moola Chotok  Chotak waterfall and Oasis in Moola, Khuzdar i...
#
#          category     district  longitude  new_column
# 15        Coastal  Balochistan  62.049984           1
# 68        Coastal  Balochistan  62.181600           1
# 1          Island  Balochistan  63.847948           1
# 19  National Park  Balochistan  65.530701           1
# 41      Waterfall  Balochistan  66.640560           1

# %%
df.sort_values(by=["longitude", "new_column"], inplace=True, ascending=[True, True])

# %%
df.head()
# Out:
#                     Name                                               Desc  \
# 15               Gawadar  Gwadar is a port city on the southwestern coas...
# 68        West Bay Beach  The West Bay Beach lies on the Makran coast, a...
# 1          Astola Island  Astola Island, also known as Jezira Haft Talar...
# 19  Hingol National Park  Hingol national park stretches out to approxim...
# 41          Moola Chotok  Chotak waterfall and Oasis in Moola, Khuzdar i...
#
#          category     district  longitude  new_column
# 15        Coastal  Balochistan  62.049984           1
# 68        Coastal  Balochistan  62.181600           1
# 1          Island  Balochistan  63.847948           1
# 19  National Park  Balochistan  65.530701           1
# 41      Waterfall  Balochistan  66.640560           1

# %%
df_Tourists = pd.read_csv("Tourists.csv", index_col=0)

# %%
df.head()
# Out:
#                     Name                                               Desc  \
# 15               Gawadar  Gwadar is a port city on the southwestern coas...
# 68        West Bay Beach  The West Bay Beach lies on the Makran coast, a...
# 1          Astola Island  Astola Island, also known as Jezira Haft Talar...
# 19  Hingol National Park  Hingol national park stretches out to approxim...
# 41          Moola Chotok  Chotak waterfall and Oasis in Moola, Khuzdar i...
#
#          category     district  longitude  new_column
# 15        Coastal  Balochistan  62.049984           1
# 68        Coastal  Balochistan  62.181600           1
# 1          Island  Balochistan  63.847948           1
# 19  National Park  Balochistan  65.530701           1
# 41      Waterfall  Balochistan  66.640560           1

# %%
df.dtypes
# Out:
# Name           object
# Desc           object
# category       object
# district       object
# longitude     float64
# new_column      int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Name', 'Desc', 'category', 'district', 'longitude', 'new_column'], dtype='object')

# %%
df.rename(columns={"category":"category_1"},inplace=False)
# Out:
#                     Name                                               Desc  \
# 15               Gawadar  Gwadar is a port city on the southwestern coas...
# 68        West Bay Beach  The West Bay Beach lies on the Makran coast, a...
# 1          Astola Island  Astola Island, also known as Jezira Haft Talar...
# 19  Hingol National Park  Hingol national park stretches out to approxim...
# 41          Moola Chotok  Chotak waterfall and Oasis in Moola, Khuzdar i...
# ..                   ...                                                ...
# 58          Satpara Lake  Satpara Lake is basically a natural lake that ...
# 35    Manthoka Waterfall  Manthoka is 600 Kms and 15.5 hours from Islama...
# 14      Farphu Waterfall  Farphu Waterfall in Bagrot Valley of Gilgit Ba...
# 7              Concordia  Amongst the tallest 14 mountain peaks of the w...
# 4        Baltoro Glacier  The Baltoro Glacier, at 63 km (39 mi) in lengt...
#
# ...

# %%
df.set_index("Name", inplace=True)

# %%
df.head()
# Out:
#                                                                    Desc  \
# Name
# Gawadar               Gwadar is a port city on the southwestern coas...
# West Bay Beach        The West Bay Beach lies on the Makran coast, a...
# Astola Island         Astola Island, also known as Jezira Haft Talar...
# Hingol National Park  Hingol national park stretches out to approxim...
# Moola Chotok          Chotak waterfall and Oasis in Moola, Khuzdar i...
#
#                            category     district  longitude  new_column
# Name
# Gawadar                     Coastal  Balochistan  62.049984           1
# West Bay Beach              Coastal  Balochistan  62.181600           1
# Astola Island                Island  Balochistan  63.847948           1
# Hingol National Park  National Park  Balochistan  65.530701           1
# Moola Chotok              Waterfall  Balochistan  66.640560           1

# %%
df.loc["Astola Island", "longitude"]
# Out:
# 63.84794782

# %%
df.set_index("longitude", inplace=False)
# Out:
#                                                         Desc       category  \
# longitude
# 62.049984  Gwadar is a port city on the southwestern coas...        Coastal
# 62.181600  The West Bay Beach lies on the Makran coast, a...        Coastal
# 63.847948  Astola Island, also known as Jezira Haft Talar...         Island
# 65.530701  Hingol national park stretches out to approxim...  National Park
# 66.640560  Chotak waterfall and Oasis in Moola, Khuzdar i...      Waterfall
# ...                                                      ...            ...
# 75.629500  Satpara Lake is basically a natural lake that ...           Lake
# 75.994797  Manthoka is 600 Kms and 15.5 hours from Islama...      Waterfall
# 75.999900  Farphu Waterfall in Bagrot Valley of Gilgit Ba...      Waterfall
# 76.511893  Amongst the tallest 14 mountain peaks of the w...    Mountainous
# 76.553142  The Baltoro Glacier, at 63 km (39 mi) in lengt...    Mountainous
#
#                    district  new_column
# ...

# %%
df["Name"]=df.index

# %%
df.set_index("longitude", inplace=True)

# %%
df.head()
# Out:
#                                                         Desc       category  \
# longitude
# 62.049984  Gwadar is a port city on the southwestern coas...        Coastal
# 62.181600  The West Bay Beach lies on the Makran coast, a...        Coastal
# 63.847948  Astola Island, also known as Jezira Haft Talar...         Island
# 65.530701  Hingol national park stretches out to approxim...  National Park
# 66.640560  Chotak waterfall and Oasis in Moola, Khuzdar i...      Waterfall
#
#               district  new_column                  Name
# longitude
# 62.049984  Balochistan           1               Gawadar
# 62.181600  Balochistan           1        West Bay Beach
# 63.847948  Balochistan           1         Astola Island
# 65.530701  Balochistan           1  Hingol National Park
# 66.640560  Balochistan           1          Moola Chotok

# %%
df.reset_index(drop=False, inplace=True)

# %%
df.head()
# Out:
#    longitude                                               Desc  \
# 0  62.049984  Gwadar is a port city on the southwestern coas...
# 1  62.181600  The West Bay Beach lies on the Makran coast, a...
# 2  63.847948  Astola Island, also known as Jezira Haft Talar...
# 3  65.530701  Hingol national park stretches out to approxim...
# 4  66.640560  Chotak waterfall and Oasis in Moola, Khuzdar i...
#
#         category     district  new_column                  Name
# 0        Coastal  Balochistan           1               Gawadar
# 1        Coastal  Balochistan           1        West Bay Beach
# 2         Island  Balochistan           1         Astola Island
# 3  National Park  Balochistan           1  Hingol National Park
# 4      Waterfall  Balochistan           1          Moola Chotok

# %%
df_missing=pd.read_csv("tourists.csv",na_values=["NaN", "not available"])

# %%
df_missing
# Out:
#                         Name  \
# 0                 Ansoo Lake
# 1              Astola Island
# 2               Attabad Lake
# 3            Badshahi Mosque
# 4            Baltoro Glacier
# ..                       ...
# 64             Taxila Museum
# 65               Thal Desert
# 66         The Lahore Museum
# 67  Umbrella Waterfall Poona
# 68            West Bay Beach
#
#                                                  Desc     category  \
# 0   Ansoo Lake is situated in Kaghan Valley of Pak...         Lake
# 1   Astola Island, also known as Jezira Haft Talar...       Island
# 2   Attabad Lake is a lake in the Gojal Valley of ...         Lake
# 3   The Badshahi Mosque is a Mughal-era congregati...       Mosque
# 4   The Baltoro Glacier, at 63 km (39 mi) in lengt...  Mountainous
# ..                                                ...          ...
# 64  Taxila Museum is located at Taxila, Punjab, Pa...       Museum
# ...

# %%
df_missing=pd.read_csv("tourists.csv",na_values={"longitude" : "not available", "latitude": -1})

# %%
df.head()
# Out:
#    longitude                                               Desc  \
# 0  62.049984  Gwadar is a port city on the southwestern coas...
# 1  62.181600  The West Bay Beach lies on the Makran coast, a...
# 2  63.847948  Astola Island, also known as Jezira Haft Talar...
# 3  65.530701  Hingol national park stretches out to approxim...
# 4  66.640560  Chotak waterfall and Oasis in Moola, Khuzdar i...
#
#         category     district  new_column                  Name
# 0        Coastal  Balochistan           1               Gawadar
# 1        Coastal  Balochistan           1        West Bay Beach
# 2         Island  Balochistan           1         Astola Island
# 3  National Park  Balochistan           1  Hingol National Park
# 4      Waterfall  Balochistan           1          Moola Chotok

# %%
df_missing=pd.read_csv("tourists.csv", na_values=["NaN","not available"])

# %%
df_missing
# Out:
#                         Name  \
# 0                 Ansoo Lake
# 1              Astola Island
# 2               Attabad Lake
# 3            Badshahi Mosque
# 4            Baltoro Glacier
# ..                       ...
# 64             Taxila Museum
# 65               Thal Desert
# 66         The Lahore Museum
# 67  Umbrella Waterfall Poona
# 68            West Bay Beach
#
#                                                  Desc     category  \
# 0   Ansoo Lake is situated in Kaghan Valley of Pak...         Lake
# 1   Astola Island, also known as Jezira Haft Talar...       Island
# 2   Attabad Lake is a lake in the Gojal Valley of ...         Lake
# 3   The Badshahi Mosque is a Mughal-era congregati...       Mosque
# 4   The Baltoro Glacier, at 63 km (39 mi) in lengt...  Mountainous
# ..                                                ...          ...
# 64  Taxila Museum is located at Taxila, Punjab, Pa...       Museum
# ...

# %%
df.isnull()
# Out:
#     longitude   Desc  category  district  new_column   Name
# 0       False  False     False     False       False  False
# 1       False  False     False     False       False  False
# 2       False  False     False     False       False  False
# 3       False  False     False     False       False  False
# 4       False  False     False     False       False  False
# ..        ...    ...       ...       ...         ...    ...
# 64      False  False     False     False       False  False
# 65      False  False     False     False       False  False
# 66      False  False     False     False       False  False
# 67      False  False     False     False       False  False
# 68      False  False     False     False       False  False
#
# [69 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# longitude     0
# Desc          0
# category      0
# district      0
# new_column    0
# Name          0
# dtype: int64

# %%
df_missing.dropna(axis=0, inplace=False)
# Out:
#                         Name  \
# 0                 Ansoo Lake
# 1              Astola Island
# 2               Attabad Lake
# 3            Badshahi Mosque
# 4            Baltoro Glacier
# ..                       ...
# 64             Taxila Museum
# 65               Thal Desert
# 66         The Lahore Museum
# 67  Umbrella Waterfall Poona
# 68            West Bay Beach
#
#                                                  Desc     category  \
# 0   Ansoo Lake is situated in Kaghan Valley of Pak...         Lake
# 1   Astola Island, also known as Jezira Haft Talar...       Island
# 2   Attabad Lake is a lake in the Gojal Valley of ...         Lake
# 3   The Badshahi Mosque is a Mughal-era congregati...       Mosque
# 4   The Baltoro Glacier, at 63 km (39 mi) in lengt...  Mountainous
# ..                                                ...          ...
# 64  Taxila Museum is located at Taxila, Punjab, Pa...       Museum
# ...

# %%
df_missing.fillna(0, inplace=False)
# Out:
#                         Name  \
# 0                 Ansoo Lake
# 1              Astola Island
# 2               Attabad Lake
# 3            Badshahi Mosque
# 4            Baltoro Glacier
# ..                       ...
# 64             Taxila Museum
# 65               Thal Desert
# 66         The Lahore Museum
# 67  Umbrella Waterfall Poona
# 68            West Bay Beach
#
#                                                  Desc     category  \
# 0   Ansoo Lake is situated in Kaghan Valley of Pak...         Lake
# 1   Astola Island, also known as Jezira Haft Talar...       Island
# 2   Attabad Lake is a lake in the Gojal Valley of ...         Lake
# 3   The Badshahi Mosque is a Mughal-era congregati...       Mosque
# 4   The Baltoro Glacier, at 63 km (39 mi) in lengt...  Mountainous
# ..                                                ...          ...
# 64  Taxila Museum is located at Taxila, Punjab, Pa...       Museum
# ...

# %%
mean_longitude=df_missing.longitude.mean()

# %%
df_missing.fillna({'longitude': mean_longitude}, inplace=False)
# Out:
#                         Name  \
# 0                 Ansoo Lake
# 1              Astola Island
# 2               Attabad Lake
# 3            Badshahi Mosque
# 4            Baltoro Glacier
# ..                       ...
# 64             Taxila Museum
# 65               Thal Desert
# 66         The Lahore Museum
# 67  Umbrella Waterfall Poona
# 68            West Bay Beach
#
#                                                  Desc     category  \
# 0   Ansoo Lake is situated in Kaghan Valley of Pak...         Lake
# 1   Astola Island, also known as Jezira Haft Talar...       Island
# 2   Attabad Lake is a lake in the Gojal Valley of ...         Lake
# 3   The Badshahi Mosque is a Mughal-era congregati...       Mosque
# 4   The Baltoro Glacier, at 63 km (39 mi) in lengt...  Mountainous
# ..                                                ...          ...
# 64  Taxila Museum is located at Taxila, Punjab, Pa...       Museum
# ...
